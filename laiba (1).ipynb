# %%
#QUESTION NO 02:

# %%
Plot the first derivative of the following function over $[-1,1]$ by using the forward, backward and central differences.

Compare the plots with the theoretical one at $h = 0.1, 0.01$ and $0.001$

$f(x) = 0.1x^5 - 0.2x^3 + 0.1x - 0.2$

Theoretical :

$f'(x) = 0.5x^4 - 0.6x^2 + 0.1$

**Formulas are given for reference**

**FORWARD FINITE DIFFERENCES**

$f'(x) = \frac{f(x_{i+1})-f(x_i)}{h}$

$f''(x) = \frac{f(x_{i+2})-2f(x_{i+1})+f(x_i)}{h^2}$

**BACKWARD FINITE DIFFERENCES**

$f'(x) = \frac{f(x_{i}-f(x_i))}{h}$

$f''(x) = \frac{f(x_{i})-2f(x_{i-1})+f(x_{i-2})}{h^2}$

**CENTRAL FINITE DIFFERENCES**

$f'(x) = \frac{f(x_{i+1})-f(x_{i-1})}{2h}$

$f''(x) = \frac{f(x_{i+1})-2f(x_i)+f(x_{i-1})}{h^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1,1,45)
# central diffrences 


dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2
x = 0.1
h = 0.001
df1 = 0.09405
df2 = -0.118
print("\t f'(x)\t\t err\t\t f''(x)\t\t err")
dff1 = (f(x+h)-f(x))/h
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
print("FFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2
print("BFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
print("CFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
# Out:
# 	 f'(x)		 err		 f''(x)		 err
# FFD	 0.093991	-0.000059	-0.119139	-0.001139
# BFD	 0.094109	 0.000059	-0.116859	 0.001141
# CFD	 0.094050	-0.000000	-0.118000	 0.000000

# %%
f=lambda x: 0.1*x**16 - 0.2*x**3 + 0.1*x - 0.2
x = 0.1
h = 0.01
df1 = 0.09405
df2 = -0.118
print("\t f'(x)\t\t err\t\t f''(x)\t\t err")
dff1 = (f(x+h)-f(x))/h
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
print("FFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2
print("BFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
print("CFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
# Out:
# 	 f'(x)		 err		 f''(x)		 err
# FFD	 0.093380	-0.000670	-0.132000	-0.014000
# BFD	 0.094580	 0.000530	-0.108000	 0.010000
# CFD	 0.093980	-0.000070	-0.120000	-0.002000

# %%
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2
x = 0.1
h = 0.1
df1 = 0.09405
df2 = -0.118
print("\t f'(x)\t\t err\t\t f''(x)\t\t err")
dff1 = (f(x+h)-f(x))/h
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
print("FFD\\t% f\\t% f\\t% f\\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2
print("BFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
print("CFD\t% f\t% f\t% f\t% f"%(dff1,dff1-df1,dff2,dff2-df2))
# Out:
# 	 f'(x)		 err		 f''(x)		 err
# FFD\t 0.086310\t-0.007740\t-0.222000\t-0.104000
# BFD	 0.098010	 0.003960	 0.000000	 0.118000
# CFD	 0.092160	-0.001890	-0.117000	 0.001000

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1,1,45)
# forward difference

dff1 = (f(x+1)-f(x))/h
dff2 = (f(x+2)-2*f(x+1)+f(x))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'-g',x,dff2,'-r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.1
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1,1,45)
# backward difference
dff1 = (f(x)-f(x))/h
dff2 = (f(x)-2*f(x-1)+f(x-2))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1,1,45)
# backward difference
dff1 = (f(x)-f(x))/h
dff2 = (f(x)-2*f(x-1)+f(x-2))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.001
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1)
# backward difference
dff1 = (f(x)-f(x))/h
dff2 = (f(x)-2*f(x-1)+f(x-2))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-8db605127127> in <module>
#       5 h = 0.001
#       6 #will create an array of elements between -1 and 1 having 45 equal
# ----> 7 x = np.linspace(-1)
#       8 # backward difference
#       9 dff1 = (f(x)-f(x))/h
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# TypeError: _linspace_dispatcher() missing 1 required positional argument: 'stop'

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.001
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1,45)
# central diffrences 


dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.12
#will create an array of elements between -1 and 1 having 45 equal
x = np.linspace(-1,1,45)
# central diffrences 


dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
from math import sin
def secant(fn,x1,x2,tol,maxiter):
    for i in range(maxiter):
        xnew  = x2 - (x2-x1)/(fn(x2)-fn(x1))*fn(x2)
        if abs(xnew-x2) < tol:
            break
        else:
            x1 = x2
            x2 = xnew
    else:
        print('warning: Maximum number of iterations is reached')
    return xnew, i

f = lambda x: 2*x**2 - 5*x + 3 

x1 = float(input('enter x1: '))
x2 = float(input('enter x2: '))

r, n = secant(f,x1,x2,1.0e-6,100)

print('Root = %f at %d1
# Out:
# enter x1: 1.4
# enter x2: 1.3
# Root = 1.500000 at 6 iterations
